# %%
#Venkat was here
# hello-world-predictor.ipynb
# Objective: Read the dataset, do a simple prediction for games on a given date using data prior to that date, then
#            and record some stats on how well it did.
# 
# Modules
import os
import csv
import pprint
import pandas as pd

# Set path for file
csvpath = os.path.join("..", "datasets", "Final_Data_Files", "GL2010.csv")
print(csvpath)

season_df = pd.read_csv(csvpath, delimiter=",")
season_df.head()
# Out:
# ../datasets/Final_Data_Files/GL2010.csv
#    20100404  0  Sun  NYA  AL  1  BOS AL.1  1.1  7  ...              J.D. Drew  \
# 0  20100405  0  Mon  MIN  AL  1  ANA   AL    1  3  ...         Howie Kendrick
# 1  20100405  0  Mon  CLE  AL  1  CHA   AL    1  0  ...        A.J. Pierzynski
# 2  20100405  0  Mon  DET  AL  1  KCA   AL    1  8  ...    Yuniesky Betancourt
# 3  20100405  0  Mon  SEA  AL  1  OAK   AL    1  5  ...             Mark Ellis
# 4  20100405  0  Mon  TOR  AL  1  TEX   AL    1  4  ...  Jarrod Saltalamacchia
#
#    9.4  camem001   Mike Cameron  8.4  scutm001     Marco Scutaro  6.5  \
# 0    4  woodb003   Brandon Wood    5  mathj001       Jeff Mathis    2
# 1    2  teahm001    Mark Teahen    5  ramia003    Alexei Ramirez    6
# 2    6  kendj001  Jason Kendall    2  getzc001        Chris Getz    4
# 3    4  buckt001    Travis Buck    7  pennc001  Cliff Pennington    6
# 4    2  blana001  Andres Blanco    4  andre001      Elvis Andrus    6
#
#    Unnamed: 159  Y
# 0           NaN  Y
# 1           NaN  Y
# 2           NaN  Y
# 3           NaN  Y
# 4           NaN  Y
#
# [5 rows x 161 columns]

# %%
season_df.shape # Useful to make sure we don't loose rows when adding column headers.
# Out:
# (2429, 161)

# %%
# Add Column headers by number
col_headers = [("Col_"+str(i)) for i in range(1,season_df.shape[1]+1)]
season_df.columns = col_headers
season_df.head()
# Out:
#       Col_1  Col_2 Col_3 Col_4 Col_5  Col_6 Col_7 Col_8  Col_9  Col_10  ...  \
# 0  20100405      0   Mon   MIN    AL      1   ANA    AL      1       3  ...
# 1  20100405      0   Mon   CLE    AL      1   CHA    AL      1       0  ...
# 2  20100405      0   Mon   DET    AL      1   KCA    AL      1       8  ...
# 3  20100405      0   Mon   SEA    AL      1   OAK    AL      1       5  ...
# 4  20100405      0   Mon   TOR    AL      1   TEX    AL      1       4  ...
#
#                  Col_152  Col_153   Col_154        Col_155  Col_156   Col_157  \
# 0         Howie Kendrick        4  woodb003   Brandon Wood        5  mathj001
# 1        A.J. Pierzynski        2  teahm001    Mark Teahen        5  ramia003
# 2    Yuniesky Betancourt        6  kendj001  Jason Kendall        2  getzc001
# 3             Mark Ellis        4  buckt001    Travis Buck        7  pennc001
# 4  Jarrod Saltalamacchia        2  blana001  Andres Blanco        4  andre001
#
#             Col_158  Col_159  Col_160 Col_161
# 0       Jeff Mathis        2      NaN       Y
# 1    Alexei Ramirez        6      NaN       Y
# 2        Chris Getz        4      NaN       Y
# 3  Cliff Pennington        6      NaN       Y
# 4      Elvis Andrus        6      NaN       Y
#
# [5 rows x 161 columns]

# %%
season_df.shape
# Out:
# (2429, 161)

# %%
season_df = season_df.rename(columns={'Col_1':'Date',
                                     'Col_4':'Visiting Team',
                                     'Col_5':'Visiting League',
                                     'Col_7':'Home Team',
                                     'Col_8':'Home League',
                                     'Col_10':'Visiting Score',
                                     'Col_11':'Home Score'})
season_df = season_df[['Date', 'Visiting Team', 'Visiting League', 'Home Team', 'Home League',
                       'Visiting Score','Home Score']]
season_df.head()
# Out:
#        Date Visiting Team Visiting League Home Team Home League  \
# 0  20100405           MIN              AL       ANA          AL
# 1  20100405           CLE              AL       CHA          AL
# 2  20100405           DET              AL       KCA          AL
# 3  20100405           SEA              AL       OAK          AL
# 4  20100405           TOR              AL       TEX          AL
#
#    Visiting Score  Home Score
# 0               3           6
# 1               0           6
# 2               8           4
# 3               5           3
# 4               4           5
